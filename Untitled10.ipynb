# %%
import matplotlib.pyplot as plt
import pandas as pd
from pandas import  DataFrame as df
import seaborn as sns
# %matplotlib inline

# %%
df2=pd.read_excel('cancer_data6 - Copy.xlsx',sheet_name='REFERRAL')

# %%
# %matplotlib inline

# %%
df1=pd.read_excel('cancer_data6 - Copy.xlsx',sheet_name="DEMOGRAPHICS")

# %%
s1=sns.pairplot(df1)
s1.fig.

# %%
s1.x_vars=['A',"b"]

# %%
s1.fig.set_figheight(20)

# %%
s1.fig.set_figwidth(15)

# %%
df2.columns.tolist()
# Out:
# [u'LOCAL_PATIENT_IDENTIFIER',
#  u'SOURCE_OF_REFERRAL_FOR_CANCER',
#  u'REFERRING_ORGANIZATION_CODE',
#  u'REFERRER_CODE',
#  u'CANCER_REFERRAL_PRIORITY_TYPES',
#  u'REFERRAL_DESION_DATE',
#  u'REFERRAL_REQUEST_RECEIVED_DATE_DF',
#  u'CONSULTANT_CODE',
#  u'MAIN_SPECIALITY_CODE',
#  u'DATE_FIRST_SEEN',
#  u'DELAY_REASON_REFERRAL_TO_FIRST_SEEN_(CANCER)',
#  u'URGENT CANCER REFERRAL TYPE',
#  u'CANCER STATUS',
#  u'WAITING_TIME_ADJUSTMENT(FIRST_SEEN)_strg',
#  u'WAITING TIME ADJUSTMENT REASON (FIRST SEEN)']

# %%
s2=sns.pairplot(data=df2,size=3.7,hue='CANCER_REFERRAL_PRIORITY_TYPES')
