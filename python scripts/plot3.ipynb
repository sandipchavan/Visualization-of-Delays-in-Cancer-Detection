# %%
import matplotlib.pyplot as plt
import pandas as pd
from pandas import  DataFrame as df
# %matplotlib inline
import seaborn as sns

# %%
import numpy as np

# %%
import datetime

# %%
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_excel('cancer_data6.xlsx',sheet_name="DEMOGRAPHICS")

# %%
df2=pd.read_excel('cancer_data5.xlsx',sheet_name='REFERRAL')

# %%
df2['REFERRAL_DESION_DATE']=df2.apply(lambda x:pd.to_datetime(x['REFERRAL_REQUEST_RECEIVED_DATE_DF'])-datetime.timedelta(days=random.randint(7,10),hours=random.randint(1,23)),axis=1)

# %%
temp=pd.concat([df1['statename'],df2],axis=1)

# %%
df2['REF']=temp.apply(lambda x:"R" if str(x['LOCAL_PATIENT_IDENTIFIER']).startswith('R') else "L",axis=1)

# %%
temp_grp=temp.groupby(['REF','statename'])

# %%
df2.to_excel('referral.xlsx')

# %%
df2['delay2']=df2['DATE_FIRST_SEEN']-df2['REFERRAL_REQUEST_RECEIVED_DATE_DF']

# %%
df2['REFERRAL_DESION_DATE']=df2.apply(lambda x:datetime.datetime.)
# Out:
#    LOCAL_PATIENT_IDENTIFIER SOURCE_OF_REFERRAL_FOR_CANCER  \
# 0                  L_CPP100                Not_Applicable
# 1                  R_CPP101   03_Referral from Consultant
# 2                  L_CPP102                Not_Applicable
# 3                  L_CPP103                Not_Applicable
# 4                  L_CPP104                Not_Applicable
# 5                  L_CPP105                Not_Applicable
# 6                  R_CPP106        05_Private Health Care
# 7                  L_CPP107                Not_Applicable
# 8                  R_CPP108   03_Referral from Consultant
# 9                  L_CPP109                Not_Applicable
# 10                 L_CPP110                Not_Applicable
# 11                 L_CPP111                Not_Applicable
# 12                 L_CPP112                Not_Applicable
# 13                 L_CPP113                Not_Applicable
# 14                 L_CPP114                Not_Applicable
# ...

# %%
temp_date=pd.DataFrame()

# %%
temp_df=pd.concat([df1['statename'],df2],axis=1)

# %%
# Out:
#    statename LOCAL_PATIENT_IDENTIFIER SOURCE_OF_REFERRAL_FOR_CANCER  \
# 0     KERALA                 L_CPP100                Not_Applicable
# 1     KERALA                 R_CPP101   03_Referral from Consultant
# 2  KARNATAKA                 L_CPP102                Not_Applicable
# 3     KERALA                 L_CPP103                Not_Applicable
# 4     KERALA                 L_CPP104                Not_Applicable
#
#   REFERRING_ORGANIZATION_CODE   REFERRER_CODE CANCER_REFERRAL_PRIORITY_TYPES  \
# 0              Not_Applicable  Not_Applicable                 Not_Applicable
# 1                 GP_Practice          GP_DR2                     02_Urgency
# 2              Not_Applicable  Not_Applicable                 Not_Applicable
# 3              Not_Applicable  Not_Applicable                 Not_Applicable
# 4              Not_Applicable  Not_Applicable                 Not_Applicable
#
#   REFERRAL_DESION_DATE REFERRAL_REQUEST_RECEIVED_DATE_DF CONSULTANT_CODE  \
# ...

# %%
def fun1(x):
    if (  str(x['statename']).startswith("KE") and str(x['REF'])=="R" ):
        return x['DATE_FIRST_SEEN']-datetime.timedelta(days=random.randint(4,5))
    if (  str(x['statename'])!="KERALA" and str(x['REF'])=="R" ):
        return x['DATE_FIRST_SEEN']-datetime.timedelta(days=random.randint(7,10),hours=random.randint(1,23))
    if (  str(x['statename'])=="KERALA" and str(x['REF'])=="L" ):
        return x['DATE_FIRST_SEEN']-datetime.timedelta(days=random.randint(2,3),hours=random.randint(1,23))
    if (  str(x['statename'])!="KERALA" and str(x['REF'])=="L" ):
        return x['DATE_FIRST_SEEN']-datetime.timedelta(days=random.randint(2,3),hours=random.randint(1,23))

# %%
temp_df['REFERRAL_RECEIVED']=temp_df.apply(fun1,axis=1)

# %%
df2['REFERRAL_DESION_DATE']=df2.apply(lambda x:x['REFERRAL_DESION_DATE']-datetime.timedelta(days=random.randint(7,9)),axis=1)

# %%
df2['REFERRAL_DESION_DATE']=temp_date['REFERRAL_DESION_DATE']

# %%
temp_df["LOCAL_PATIENT_IDENTIFIER"]=temp_df.apply(lambda x:str(x['LOCAL_PATIENT_IDENTIFIER']).replace("L","R") if pd.to_datetime(x['WAITING_TIME_ADJUSTMENT(FIRST_SEEN)_strg'])>,axis=1)
# Out:
#   LOCAL_PATIENT_IDENTIFIER SOURCE_OF_REFERRAL_FOR_CANCER  \
# 0                 L_CPP100                Not_Applicable
# 1                 R_CPP101   03_Referral from Consultant
# 2                 L_CPP102                Not_Applicable
# 3                 L_CPP103                Not_Applicable
# 4                 L_CPP104                Not_Applicable
#
#   REFERRING_ORGANIZATION_CODE   REFERRER_CODE CANCER_REFERRAL_PRIORITY_TYPES  \
# 0              Not_Applicable  Not_Applicable                 Not_Applicable
# 1                 GP_Practice          GP_DR2                     02_Urgency
# 2              Not_Applicable  Not_Applicable                 Not_Applicable
# 3              Not_Applicable  Not_Applicable                 Not_Applicable
# 4              Not_Applicable  Not_Applicable                 Not_Applicable
#
#   REFERRAL_DESION_DATE REFERRAL_REQUEST_RECEIVED_DATE_DF CONSULTANT_CODE  \
# 0  2013-02-27 13:37:09               2017-01-06 21:37:09         GMP-DR3
# ...

# %%
df2.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER SOURCE_OF_REFERRAL_FOR_CANCER  \
# 0                 L_CPP100                Not_Applicable
# 1                 R_CPP101   03_Referral from Consultant
# 2                 L_CPP102                Not_Applicable
# 3                 L_CPP103                Not_Applicable
# 4                 L_CPP104                Not_Applicable
#
#   REFERRING_ORGANIZATION_CODE   REFERRER_CODE CANCER_REFERRAL_PRIORITY_TYPES  \
# 0              Not_Applicable  Not_Applicable                 Not_Applicable
# 1                 GP_Practice          GP_DR2                     02_Urgency
# 2              Not_Applicable  Not_Applicable                 Not_Applicable
# 3              Not_Applicable  Not_Applicable                 Not_Applicable
# 4              Not_Applicable  Not_Applicable                 Not_Applicable
#
#   REFERRAL_DESION_DATE REFERRAL_REQUEST_RECEIVED_DATE_DF CONSULTANT_CODE  \
# 0  2016-12-29 19:37:09               2017-01-06 21:37:09         GMP-DR3
# ...

# %%
df2.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER SOURCE_OF_REFERRAL_FOR_CANCER  \
# 0                 L_CPP100                Not_Applicable
# 1                 R_CPP101   03_Referral from Consultant
# 2                 L_CPP102                Not_Applicable
# 3                 L_CPP103                Not_Applicable
# 4                 L_CPP104                Not_Applicable
#
#   REFERRING_ORGANIZATION_CODE   REFERRER_CODE CANCER_REFERRAL_PRIORITY_TYPES  \
# 0              Not_Applicable  Not_Applicable                 Not_Applicable
# 1                 GP_Practice          GP_DR2                     02_Urgency
# 2              Not_Applicable  Not_Applicable                 Not_Applicable
# 3              Not_Applicable  Not_Applicable                 Not_Applicable
# 4              Not_Applicable  Not_Applicable                 Not_Applicable
#
#   REFERRAL_DESION_DATE REFERRAL_REQUEST_RECEIVED_DATE_DF CONSULTANT_CODE  \
# 0  2016-12-28 14:37:09               2017-01-06 21:37:09         GMP-DR3
# ...

# %%
df2['delay3']=df2['WAITING_TIME_ADJUSTMENT(FIRST_SEEN)_strg']

# %%
df2.to_excel('referal_delays.xlsx',index=None)

# %%
df3=pd.read_excel('cancer_data6.xlsx',sheet_name='IMAGING')

# %%
d=pd.read_excel('cancer_data5.xlsx',sheet_name='REFERRAL')

# %%
df2['delay3']=df2['DATE_FIRST_SEEN']-df3['CLINICAL_INTERVENTION_DATES(CANCER_IMAGING)']

# %%
df2['delay2']=df3['CLINICAL_INTERVENTION_DATES(CANCER_IMAGING)']-df2['REFERRAL_REQUEST_RECEIVED_DATE_DF']

# %%
df2['REFERRAL_DESION_DATE']=d['REFERRAL_DESION_DATE']

# %%
df2.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER SOURCE_OF_REFERRAL_FOR_CANCER  \
# 0                 L_CPP100                Not_Applicable
# 1                 R_CPP101   03_Referral from Consultant
# 2                 L_CPP102                Not_Applicable
# 3                 L_CPP103                Not_Applicable
# 4                 L_CPP104                Not_Applicable
#
#   REFERRING_ORGANIZATION_CODE   REFERRER_CODE CANCER_REFERRAL_PRIORITY_TYPES  \
# 0              Not_Applicable  Not_Applicable                 Not_Applicable
# 1                 GP_Practice          GP_DR2                     02_Urgency
# 2              Not_Applicable  Not_Applicable                 Not_Applicable
# 3              Not_Applicable  Not_Applicable                 Not_Applicable
# 4              Not_Applicable  Not_Applicable                 Not_Applicable
#
#   REFERRAL_DESION_DATE REFERRAL_REQUEST_RECEIVED_DATE_DF CONSULTANT_CODE  \
# 0  2017-01-01 11:59:09               2017-01-06 21:37:09         GMP-DR3
# ...

# %%
df4=pd.read_excel('cancer_data6.xlsx',sheet_name='DIAGNOSIS')

# %%
df2=pd.concat([df2,df1['statename']],axis=1)

# %%
df2[(df2['statename']!="KERALA") & (df2['REF']=="R")]['delay1'].mean()
# Out:
# Timedelta('8 days 22:51:11.428571')

# %%
df2['delay01']=df2['REFERRAL_DESION_DATE']-df4["DIAGNOSIS DATE (CANCER)"]

# %%
#df2.rename(columns={"delay01":"Delay1_diagnos&decisionDate"},inplace=True)

# %%
df2.drop(columns=['delay1'],axis=1,inplace=True)

# %%
df2.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER SOURCE_OF_REFERRAL_FOR_CANCER  \
# 0                 L_CPP100                Not_Applicable
# 1                 R_CPP101   03_Referral from Consultant
# 2                 L_CPP102                Not_Applicable
# 3                 L_CPP103                Not_Applicable
# 4                 L_CPP104                Not_Applicable
#
#   REFERRING_ORGANIZATION_CODE   REFERRER_CODE CANCER_REFERRAL_PRIORITY_TYPES  \
# 0              Not_Applicable  Not_Applicable                 Not_Applicable
# 1                 GP_Practice          GP_DR2                     02_Urgency
# 2              Not_Applicable  Not_Applicable                 Not_Applicable
# 3              Not_Applicable  Not_Applicable                 Not_Applicable
# 4              Not_Applicable  Not_Applicable                 Not_Applicable
#
#   REFERRAL_DESION_DATE REFERRAL_REQUEST_RECEIVED_DATE_DF CONSULTANT_CODE  \
# 0  2017-01-01 11:59:09               2017-01-06 21:37:09         GMP-DR3
# ...

# %%
df2['delay2_decisionDate&ReceivedDate']=df2["REFERRAL_REQUEST_RECEIVED_DATE_DF"]-df2['REFERRAL_DESION_DATE']

# %%
df2.to_excel("delays_ref.xlsx",index=None)

# %%
df2['delay3_clinicalIntrvnt&ReqReceivedDate']=df3['CLINICAL_INTERVENTION_DATES(CANCER_IMAGING)']-df2['REFERRAL_REQUEST_RECEIVED_DATE_DF']

# %%
df2['delay4_dateFirstSeen&ClinicalIntervention']=df2['DATE_FIRST_SEEN']-df3['CLINICAL_INTERVENTION_DATES(CANCER_IMAGING)']

# %%
df2.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER SOURCE_OF_REFERRAL_FOR_CANCER  \
# 0                 L_CPP100                Not_Applicable
# 1                 R_CPP101   03_Referral from Consultant
# 2                 L_CPP102                Not_Applicable
# 3                 L_CPP103                Not_Applicable
# 4                 L_CPP104                Not_Applicable
#
#   REFERRING_ORGANIZATION_CODE   REFERRER_CODE CANCER_REFERRAL_PRIORITY_TYPES  \
# 0              Not_Applicable  Not_Applicable                 Not_Applicable
# 1                 GP_Practice          GP_DR2                     02_Urgency
# 2              Not_Applicable  Not_Applicable                 Not_Applicable
# 3              Not_Applicable  Not_Applicable                 Not_Applicable
# 4              Not_Applicable  Not_Applicable                 Not_Applicable
#
#   REFERRAL_DESION_DATE REFERRAL_REQUEST_RECEIVED_DATE_DF CONSULTANT_CODE  \
# 0  2017-01-01 11:59:09               2017-01-06 21:37:09         GMP-DR3
# ...

# %%
df5=pd.read_excel('cancer_data6.xlsx',sheet_name='CANCER CARE PLAN')

# %%
df2['delay5_discussionDate&DateFirstSeen']=df5['MULTIDISCIPLINARY TEAM DISCUSSION DATE']-df2['DATE_FIRST_SEEN']

# %%
#need for analysis#df2['delay6_carePlanagreedDate&DateFirstSeen']=df5['CARE PLAN AGREED DATE']-df2['DATE_FIRST_SEEN']

# %%
df2['delay7_carePlanAgreedDate&DiscussionDate']=df5['CARE PLAN AGREED DATE']-df5['MULTIDISCIPLINARY TEAM DISCUSSION DATE']

# %%
df2.drop(columns=['delay6_carePlanagreedDate&DateFirstSeen'],inplace=True)

# %%
df7=pd.read_excel('cancer_data6.xlsx',sheet_name='Surgery&other procedures')

# %%
df2['delay8_decisionToTreatDate&SurgeryToTreatDate']=df7['DECISION TO TREAT DATE (SURGERY)']-df5['CARE PLAN AGREED DATE']

# %%
df2['delay9_startDate&DecisionTOTreatDate']=df7['START DATE (SURGERY HOSPITAL PROVIDER SPELL)']-df7['DECISION TO TREAT DATE (SURGERY)']

# %%
df2['delay10_procedureDate&StartDate']=df7['PROCEDURE DATE']-df7['START DATE (SURGERY HOSPITAL PROVIDER SPELL)']

# %%
df2.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER SOURCE_OF_REFERRAL_FOR_CANCER  \
# 0                 L_CPP100                Not_Applicable
# 1                 R_CPP101   03_Referral from Consultant
# 2                 L_CPP102                Not_Applicable
# 3                 L_CPP103                Not_Applicable
# 4                 L_CPP104                Not_Applicable
#
#   REFERRING_ORGANIZATION_CODE   REFERRER_CODE CANCER_REFERRAL_PRIORITY_TYPES  \
# 0              Not_Applicable  Not_Applicable                 Not_Applicable
# 1                 GP_Practice          GP_DR2                     02_Urgency
# 2              Not_Applicable  Not_Applicable                 Not_Applicable
# 3              Not_Applicable  Not_Applicable                 Not_Applicable
# 4              Not_Applicable  Not_Applicable                 Not_Applicable
#
#   REFERRAL_DESION_DATE REFERRAL_REQUEST_RECEIVED_DATE_DF CONSULTANT_CODE  \
# 0  2017-01-01 11:59:09               2017-01-06 21:37:09         GMP-DR3
# ...

# %%
df2['delay11_DischargeDate&procedureDate']=df7['DISCHARGE DATE (HOSPITAL PROVIDER SPELL)']-df7['PROCEDURE DATE']

# %%
df8=pd.read_excel('cancer_data6.xlsx',sheet_name='Pathology Details')

# %%
df2['delay12_sampleReceiptDate&DischargeDate']=df8['SAMPLE RECEIPT DATE']-df7['DISCHARGE DATE (HOSPITAL PROVIDER SPELL)']

# %%
df2['delay13_investigationResultDate&sampleReciptDate']=df8['INVESTIGATION RESULT DATE']-df8['SAMPLE RECEIPT DATE']

# %%
df9=pd.read_excel("cancer_data6.xlsx",sheet_name="chemotheropy & other drugs")

# %%
df2['delay14_decisionToTreat_chemo&investigationREsultdate']=df9["DECISION TO TREAT DATE (ANTI-CANCER DRUG REGIMEN)"]-df8['INVESTIGATION RESULT DATE']

# %%
df2['delay15_startDate_chemo&decisionToTreat_chemo']=df9["START DATE (ANTI-CANCER DRUG FRACTION)"]-df9["DECISION TO TREAT DATE (ANTI-CANCER DRUG REGIMEN)"]

# %%
df10=pd.read_excel("cancer_data6.xlsx",sheet_name="Radiotherapy(Teletherapy)")

# %%
df2["delay16_decisionToTreat_tele&StartDate_chemo"]=df10['DECISION TO TREAT DATE (TELETHERAPY TREATMENT COURSE)']-df9["START DATE (ANTI-CANCER DRUG FRACTION)"]

# %%
df2["delay17_StartDAte_tele&treatDate_tele"]=df10["START DATE (TELETHERAPY TREATMENT COURSE)"]-df10["DECISION TO TREAT DATE (TELETHERAPY TREATMENT COURSE)"]

# %%
df11=pd.read_excel("cancer_data6.xlsx",sheet_name='Radiotherapy(Brachytherapy)')

# %%
df2["delay18_treatDateBrach&StartDate_tele"]=df11['DECISION TO TREAT DATE (BRACHYTHERAPY TREATMENT COURSE)']-df10['DECISION TO TREAT DATE (TELETHERAPY TREATMENT COURSE)']

# %%
df2["delay19_startDate_brach&treatDate_brach"]=df11['START DATE (BRACHYTHERAPY TREATMENT COURSE)']-df11["DECISION TO TREAT DATE (BRACHYTHERAPY TREATMENT COURSE)"]

# %%
df2["delay20_endDate_brach&StartDate_brach"]=df11['END DATE (BRACHYTHERAPY TREATMENT COURSE)']-df11['START DATE (BRACHYTHERAPY TREATMENT COURSE)']

# %%
df14=pd.read_excel("cancer_data6.xlsx",sheet_name='Clinical Status Assesment')

# %%
df2["delay21_statusAssesmentDate&EndDate_brach"]=df14['CLINICAL STATUS ASSESSMENT DATE (CANCER)']-df11["END DATE (BRACHYTHERAPY TREATMENT COURSE)"]

# %%
df15=pd.read_excel("cancer_data6.xlsx",sheet_name='Death Details')

# %%
temp=pd.concat([df14,df15],axis=1)

# %%
temp.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER CLINICAL STATUS ASSESSMENT DATE (CANCER)  \
# 0                 L_CPP100                               2017-05-09
# 1                 R_CPP101                               2017-06-02
# 2                 L_CPP102                               2017-06-02
# 3                 L_CPP103                               2017-05-22
# 4                 L_CPP104                               2017-06-03
#
#         PRIMARY TUMOUR STATUS                          NODAL STATUS  \
# 0                 5_Uncertain                           5_Uncertain
# 1   1_Residual primary tumour                        4_Not assessed
# 2                 5_Uncertain       3_New regional nodal metastases
# 3  3_Recurrent primary tumour  1_Residual regional nodal metastases
# 4                 5_Uncertain  1_Residual regional nodal metastases
#
#                METASTATIC STATUS MARKER RESPONSE STATUS  \
# 0       3_New distant metastases            1_No marker
# ...

# %%
def fun2(x):
    if str(x["PERSON DEATH DATE1"]).startswith('-'):
        return '-'
    if str(x["PERSON DEATH DATE1"])!='-':
        return x["PERSON DEATH DATE1"]-x["CLINICAL STATUS ASSESSMENT DATE (CANCER)"]

# %%
df2["delay22_DeathDate&AssesmentDate"]=temp.apply(fun2,axis=1)

# %%
sum_days=df2.loc[:,"Delay1_diagnos&decisionDate":]

# %%
sum_days.drop(columns=['delay9_startDate&DecisionTOTreatDate','delay14_decisionToTreat_chemo&investigationREsultdate'],inplace=True,axis=1)

# %%
sum_days.drop(columns=['delay12_sampleReceiptDate&DischargeDate','delay16_decisionToTreat_tele&StartDate_chemo'],inplace=True,axis=1)

# %%
sum_df=df(sum_days.sum(axis=1))

# %%
len(range(0,18))
# Out:
# 18

# %%
df2.to_excel('referal_delays.xlsx',index=None)

# %%
sum_days.head()
# Out:
#    Delay1_diagnos&decisionDate  delay2_decisionDate&ReceivedDate  \
# 0                     4.333333                          5.401389
# 1                     3.125000                          5.401389
# 2                     3.333333                          5.401389
# 3                     4.041667                          5.401389
# 4                     4.333333                          5.401389
#
#    delay3_clinicalIntrvnt&ReqReceivedDate  \
# 0                                6.333333
# 1                                6.625000
# 2                               11.583333
# 3                                5.250000
# 4                                6.458333
#
#    delay4_dateFirstSeen&ClinicalIntervention  \
# 0                                  13.000000
# 1                                  15.750000
# 2                                  24.791667
# 3                                  18.041667
# 4                                  12.958333
#
# ...

# %%
l=df(sum_days.iloc[0,0:]).values.tolist()

# %%
len(l)
# Out:
# 18

# %%
l1=df(sum_days.iloc[0,0:]).values

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fb80c80bb0c7> in <module>()
# ----> 1 sum_days
#
# NameError: name 'sum_days' is not defined

# %%
type(l1)
# Out:
# numpy.ndarray

# %%
l1=np.insert(l1,0,0)

# %%
l1
# Out:
# array([   0.        ,    4.33333333,    5.40138889,    6.33333333,
#          13.        ,   14.25      ,   13.04166667,    0.        ,
#           6.33333333,  245.        ,   13.16666667,    2.16666667,
#           2.16666667,   17.47420139,    0.        ,   34.47420139,
#          21.        ,   20.        ,  185.        ])

# %%
sum_days.
# Out:
#    Delay1_diagnos&decisionDate  delay2_decisionDate&ReceivedDate  \
# 0                     4.333333                          5.401389
# 1                     3.125000                          5.401389
# 2                     3.333333                          5.401389
# 3                     4.041667                          5.401389
# 4                     4.333333                          5.401389
#
#    delay3_clinicalIntrvnt&ReqReceivedDate  \
# 0                                6.333333
# 1                                6.625000
# 2                               11.583333
# 3                                5.250000
# 4                                6.458333
#
#    delay4_dateFirstSeen&ClinicalIntervention  \
# 0                                  13.000000
# 1                                  15.750000
# 2                                  24.791667
# 3                                  18.041667
# 4                                  12.958333
#
# ...

# %%
import pylab
def uniqueish_color():
    """There're better ways to generate unique colors, but this isn't awful."""
    return plt.cm.gist_ncar(np.random.random())
lst=['DIAGNOSIS DATE (CANCER)','CANCER REFERRAL DECISION DATE',"REFERRAL REQUEST RECEIVED DATE",\
     'CLINICAL INTERVENTION DATE \n(CANCER IMAGING)','DATE FIRST SEEN','MULTIDISCIPLINARY TEAM\n DISCUSSION DATE',\
     'CARE PLAN AGREED DATE']
names = lst
fig,ax=plt.subplots(figsize=(20,19))
for i in range(0,620):
    l1=df(sum_days.iloc[i,0:]).values
    l1=np.insert(l1,0,0)
    days = l1[0:7]
    
    x = range(len(lst))
    plt.xticks(x, names)
    plt.plot(x,days,color=uniqueish_color(),marker='o',markerfacecolor="b",markeredgewidth=4,markersize=12,label="patient-"+str(i))
plt.title("First Level Delay",fontsize=30,style='oblique',weight='heavy')
plt.xlabel("Sub Level Delays",fontsize=27,weight='bold')
plt.ylabel('Number of Days',fontsize=27,weight='bold')
xlabels = ax.get_xticklabels()
plt.setp(xlabels, rotation=20, fontsize=14,weight='semibold')
ylabels = ax.get_yticklabels()
plt.setp(ylabels, fontsize=14,weight='semibold')
#plt.legend(fontsize=15)
plt.savefig("First_level_delay_ofallPatients.png")
plt.show()

# %%
xy = (np.random.random((10, 2)) - 0.5).cumsum(axis=0)

# %%
np.random.random((10,2))
# Out:
# array([[ 0.88140505,  0.89732957],
#        [ 0.50280647,  0.10843271],
#        [ 0.66663769,  0.29170795],
#        [ 0.10229186,  0.6475859 ],
#        [ 0.60758176,  0.3381331 ],
#        [ 0.3392492 ,  0.20375806],
#        [ 0.05735746,  0.76325213],
#        [ 0.59475469,  0.7999451 ],
#        [ 0.29251843,  0.4947456 ],
#        [ 0.01738913,  0.02814922]])

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [0,5,9,10,15]
y = [0,1,2,3,4]
plt.plot(x,y)
plt.xticks([np.arange(min(x), max(x)+1, 1.0)])
plt.show()

# %%
df2=pd.read_excel('referal_delays.xlsx')

# %%
secondLevelDelay=pd.read_excel('secondLevelDelay.xlsx')

# %%
import pylab
def uniqueish_color():
    """There're better ways to generate unique colors, but this isn't awful."""
    return plt.cm.gist_ncar(np.random.random())
lst=['INVESTIGATION RESULT DATE','CARE PLAN AGREED DATE']
names = lst
fig,ax=plt.subplots(figsize=(20,19))
for i in range(0,620):
    l1=df(secondLevelDelay.iloc[i,0:]).values
    l1=np.insert(l1,0,0)
    days = l1[0:2]
    
    x = range(len(lst))
    plt.xticks(x, names)
    plt.plot(x,days,color=uniqueish_color(),marker='o',markerfacecolor="b",markeredgewidth=4,markersize=12,lw=1.5,label="patient-"+str(i))
plt.title("Second Level Delay",fontsize=30,style='oblique',weight='heavy')
plt.xlabel("Sub Level Delays",fontsize=27,weight='bold')
plt.ylabel('Number of Days',fontsize=27,weight='bold')
xlabels = ax.get_xticklabels()
plt.setp(xlabels, rotation=20, fontsize=14,weight='semibold')
ylabels = ax.get_yticklabels()
plt.setp(ylabels, fontsize=14,weight='semibold')
#plt.legend(fontsize=15)
plt.savefig("second_level_DelayforAllpatients.png")
plt.show()

# %%
secondLevel=secondLevelDelay['delay2_startDatesugeryspell&InvestigationResultDate']

# %%
secondLevel=df(secondLevel)

# %%
# Out:
# 0    22
# 1    21
# 2    21
# 3    22
# 4    21
# Name: delay2_startDatesugeryspell&InvestigationResultDate, dtype: int64

# %%
import pylab
def uniqueish_color():
    """There're better ways to generate unique colors, but this isn't awful."""
    return plt.cm.gist_ncar(np.random.random())
lst=['INVESTIGATION RESULT DATE','START DATE (SURGERY HOSPITAL PROVIDER SPELL)']
names = lst
fig,ax=plt.subplots(figsize=(20,19))
for i in range(0,7):
    l1=df(secondLevel.iloc[i,0:]).values
    l1=np.insert(l1,0,0)
    days = l1[0:2]
    x = range(len(lst))
    plt.xticks(x, names)
    plt.plot(x,days,color=uniqueish_color(),marker='o',markerfacecolor="b",markeredgewidth=4,markersize=12,lw=1.5,ls='--',label="patient-"+str(i))
plt.title("Second Level Delay",fontsize=30,style='oblique',weight='heavy')
plt.xlabel("Sub Level Delays",fontsize=27,weight='bold')
plt.ylabel('Number of Days',fontsize=27,weight='bold')
xlabels = ax.get_xticklabels()
plt.setp(xlabels, fontsize=14,weight='semibold')
ylabels = ax.get_yticklabels()
plt.setp(ylabels, fontsize=14,weight='semibold')
plt.legend(fontsize=15)
plt.savefig("second_level_Delay02for7patients.png")
plt.show()

# %%
secondLevel=secondLevelDelay['delay3_startDateAntiCancerRegime&investigationResultDate']

# %%
secondLevel=df(secondLevel)

# %%
import pylab
def uniqueish_color():
    """There're better ways to generate unique colors, but this isn't awful."""
    return plt.cm.gist_ncar(np.random.random())
lst=['INVESTIGATION RESULT DATE','START DATE (ANTI-CANCER DRUG REGIMEN)']
names = lst
fig,ax=plt.subplots(figsize=(20,19))
for i in range(0,1):
    l1=df(secondLevel.iloc[i,0:]).values
    l1=np.insert(l1,0,0)
    days = l1[0:2]
    x = range(len(lst))
    plt.xticks(x, names)
    plt.plot(x,days,color=uniqueish_color(),marker='o',markerfacecolor="b",markeredgewidth=4,markersize=12,lw=1.5,ls='--',label="patient-"+str(i))
plt.title("Second Level Delay",fontsize=30,style='oblique',weight='heavy')
plt.xlabel("Sub Level Delays",fontsize=27,weight='bold')
plt.ylabel('Number of Days',fontsize=27,weight='bold')
xlabels = ax.get_xticklabels()
plt.setp(xlabels, fontsize=14,weight='semibold')
ylabels = ax.get_yticklabels()
plt.setp(ylabels, fontsize=14,weight='semibold')
plt.legend(fontsize=15)
plt.savefig("second_level_Delay03for1patients.png")
plt.show()

# %%
secondLevel=secondLevelDelay['delay4_startDateTele&InvestigationResultDate']

# %%
secondLevel=df(secondLevel)

# %%
import pylab
def uniqueish_color():
    """There're better ways to generate unique colors, but this isn't awful."""
    return plt.cm.gist_ncar(np.random.random())
lst=['INVESTIGATION RESULT DATE','START DATE (TELETHERAPY TREATMENT COURSE)']
names = lst
fig,ax=plt.subplots(figsize=(20,19))
for i in range(0,620):
    l1=df(secondLevel.iloc[i,0:]).values
    l1=np.insert(l1,0,0)
    days = l1[0:2]
    x = range(len(lst))
    plt.xticks(x, names)
    plt.plot(x,days,color=uniqueish_color(),marker='o',markerfacecolor="b",markeredgewidth=4,markersize=12,label="patient-"+str(i))
plt.title("Second Level Delay",fontsize=30,style='oblique',weight='heavy')
plt.xlabel("Sub Level Delays",fontsize=27,weight='bold')
plt.ylabel('Number of Days',fontsize=27,weight='bold')
xlabels = ax.get_xticklabels()
plt.setp(xlabels, fontsize=14,weight='semibold')
ylabels = ax.get_yticklabels()
plt.setp(ylabels, fontsize=14,weight='semibold')
#plt.legend(fontsize=15)
plt.savefig("second_level_Delay04forallpatients.png")
plt.show()

# %%
secondLevel=secondLevelDelay['delay5_startDateBrach&InvestigationResultDate']

# %%
secondLevel=df(secondLevel)

# %%
import pylab
def uniqueish_color():
    """There're better ways to generate unique colors, but this isn't awful."""
    return plt.cm.gist_ncar(np.random.random())
lst=['INVESTIGATION RESULT DATE','START DATE (BRACHYTHERAPY TREATMENT COURSE)']
names = lst
fig,ax=plt.subplots(figsize=(20,19))
for i in range(0,620):
    l1=df(secondLevel.iloc[i,0:]).values
    l1=np.insert(l1,0,0)
    days = l1[0:2]
    x = range(len(lst))
    plt.xticks(x, names)
    plt.plot(x,days,color=uniqueish_color(),marker='o',markerfacecolor="b",markeredgewidth=4,markersize=12,label="patient-"+str(i))
plt.title("Second Level Delay",fontsize=30,style='oblique',weight='heavy')
plt.xlabel("Sub Level Delays",fontsize=27,weight='bold')
plt.ylabel('Number of Days',fontsize=27,weight='bold')
xlabels = ax.get_xticklabels()
plt.setp(xlabels, fontsize=14,weight='semibold')
ylabels = ax.get_yticklabels()
plt.setp(ylabels, fontsize=14,weight='semibold')
#plt.legend(fontsize=15)
plt.savefig("second_level_Delay05forallpatients.png")
plt.show()

# %%
mean_df=pd.read_excel("referal_delays.xlsx")

# %%
mean_df=mean_df.loc[:,'Delay1_diagnos&decisionDate': u'delay8_decisionToTreatDate&SurgeryToTreatDate'].dropna()

# %%
df(mean_df.max()).to_excel("Average_FirstLevelDelay.xlsx")
