# %%
import pandas as pd
from pandas import DataFrame as df
import random
import datetime

# %%
#from datetime import datetime
#from datetime import date

# %%
working_sheet2=pd.read_csv("sheet2.csv")

# %%
working_sheet1=pd.read_csv("sheet1.csv")

# %%
#working_sheet2.to_excel(writer,sheet_name="REFERRAL",index=None)

# %%
#cancer_data_sheet2['REFERRAL_RECEIVED_DATE']=cancer_data_sheet2['RE']

# %%
h1=open("ref_decision_date.csv",'w')
for i in range(0,900):
    h1.write(str(datetime.datetime(random.randint(2017,2017),random.randint(1,10),random.randint(1,28),random.randint(0,23),random.randint(1,59),random.randint(1,59)))+"\n")
h1.close()

# %%
ref_decision_date_df=pd.read_csv('ref_decision_date.csv',header=None,names=["REFERRAL_DESION_DATE"])

# %%
df1=ref_decision_date_df['REFERRAL_DESION_DATE'].apply(lambda x:datetime.datetime.strptime(x,"%Y-%m-%d %H:%M:%S"))

# %%
sorted_df=df1.sort_values(axis=0).reset_index(drop=True)

# %%
sorted_df=df(sorted_df)

# %%
#sorted_df

# %%
#REFERRAL_REQUEST_RECEIVED_DATE_DF.rename(columns={"REFERRAL_DESION_DATE":"REFERRAL_REQUEST_RECEIVED_DATE"},inplace=True)

# %%
#.to_excel(writer,sheet_name='REFERRAL')

# %%
wokng=pd.concat([working_sheet2,sorted_df],axis=1)

# %%
wokng.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER SOURCE_OF_REFERRAL_FOR_CANCER  \
# 0                 L_CPP100                Not_Applicable
# 1                 R_CPP101   03_Referral from Consultant
# 2                 L_CPP102                Not_Applicable
# 3                 L_CPP103                Not_Applicable
# 4                 L_CPP104                Not_Applicable
#
#   REFERRING_ORGANIZATION_CODE   REFERRER_CODE CANCER_REFERRAL_PRIORITY_TYPES  \
# 0              Not_Applicable  Not_Applicable                      01_Urgent
# 1                 GP_Practice          GP_DR2                      01_Urgent
# 2              Not_Applicable  Not_Applicable                     02_Urgency
# 3              Not_Applicable  Not_Applicable                      01_Urgent
# 4              Not_Applicable  Not_Applicable                     02_Urgency
#
#   REFERRAL_DESION_DATE
# 0  2017-01-01 11:59:09
# 1  2017-01-01 23:28:57
# 2  2017-01-02 14:35:24
# 3  2017-01-02 17:10:52
# 4  2017-01-02 19:33:12

# %%
writer = pd.ExcelWriter('cancer_data.xlsx', engine='xlsxwriter')
working_sheet1.to_excel(writer,sheet_name="DEMOGRAPHICS",index=None)
wokng.to_excel(writer,sheet_name='REFERRAL',index=None)
writer.save()

# %%
wokng['REFERRAL_REQUEST_RECEIVED_DATE_DF']=sorted_df.apply(lambda x:x+datetime.timedelta(days=random.randint(3,6),hours=random.randint(0,18),minutes=random.randint(1,55)))

# %%
writer = pd.ExcelWriter('cancer_data.xlsx', engine='xlsxwriter')
working_sheet1.to_excel(writer,sheet_name="DEMOGRAPHICS",index=None)
wokng.to_excel(writer,sheet_name='REFERRAL',index=None)
writer.save()

# %%
wokng.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER SOURCE_OF_REFERRAL_FOR_CANCER  \
# 0                 L_CPP100                Not_Applicable
# 1                 R_CPP101   03_Referral from Consultant
# 2                 L_CPP102                Not_Applicable
# 3                 L_CPP103                Not_Applicable
# 4                 L_CPP104                Not_Applicable
#
#   REFERRING_ORGANIZATION_CODE   REFERRER_CODE CANCER_REFERRAL_PRIORITY_TYPES  \
# 0              Not_Applicable  Not_Applicable                      01_Urgent
# 1                 GP_Practice          GP_DR2                      01_Urgent
# 2              Not_Applicable  Not_Applicable                     02_Urgency
# 3              Not_Applicable  Not_Applicable                      01_Urgent
# 4              Not_Applicable  Not_Applicable                     02_Urgency
#
#   REFERRAL_DESION_DATE REFERRAL_REQUEST_RECEIVED_DATE_DF
# 0  2017-01-01 11:59:09               2017-01-06 21:37:09
# ...

# %%
consultant_code=["GMP-DR1","GMP-DR2","GMP-DR3","GMP-DR4"]*900
consultant_code_sa=random.sample(consultant_code,900)

# %%
h3=open("consultant_code.csv",'w')
for i in consultant_code_sa:
    h3.write(i+"\n")
h3.close()

# %%
wokng['CONSULTANT_CODE']=pd.read_csv('consultant_code.csv',header=None,names=["CONSULTANT_CODE"])
#wokng.head()

# %%
writer = pd.ExcelWriter('cancer_data.xlsx', engine='xlsxwriter')
working_sheet1.to_excel(writer,sheet_name="DEMOGRAPHICS",index=None)
wokng.to_excel(writer,sheet_name='REFERRAL',index=None)
writer.save()

# %%
cancer_data_sheet1=pd.read_excel("cancer_data.xlsx",sheet_name="DEMOGRAPHICS")

# %%
cancer_data_sheet2=pd.read_excel("cancer_data.xlsx",sheet_name="REFERRAL")

# %%
cancer_data_sheet1.head()
# Out:
#    NHS NUMBER LOCAL_PATIENT_IDENTIFIER      NAME GENDER  AGE  pincode  \
# 0      101111                 CPP100_l   Addison      M   75   678572
# 1      101112                 CPP101_r    Darrel      M   39   679333
# 2      101114                 CPP102_l     Jerry      M   47   577132
# 3      101115                 CPP103_r    Karina      F   78   686693
# 4      101117                 CPP105_l  Madeline      F   67   679307
#
#            Taluk  statename CARE_SPELL_IDENTIFIER       GMP ETHNIC_CATEGORY
# 0        Alathur     KERALA                   OWN  GMP-DR11             BPL
# 1       Nilambur     KERALA                 GOV-A  GMP-DR19             HCL
# 2       Mudigere  KARNATAKA           GOV-DEFENCE   GMP-DR2             MCL
# 3  Kothamangalam     KERALA           GOV-RAILWAY   GMP-DR4             HCL
# 4     Ottappalam     KERALA           GOV-DEFENCE   GMP-DR4             MCL

# %%
cancer_data_sheet2.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER SOURCE_OF_REFERRAL_FOR_CANCER  \
# 0                 L_CPP100                Not_Applicable
# 1                 R_CPP101   03_Referral from Consultant
# 2                 L_CPP102                Not_Applicable
# 3                 L_CPP103                Not_Applicable
# 4                 L_CPP104                Not_Applicable
#
#   REFERRING_ORGANIZATION_CODE   REFERRER_CODE CANCER_REFERRAL_PRIORITY_TYPES  \
# 0              Not_Applicable  Not_Applicable                      01_Urgent
# 1                 GP_Practice          GP_DR2                      01_Urgent
# 2              Not_Applicable  Not_Applicable                     02_Urgency
# 3              Not_Applicable  Not_Applicable                      01_Urgent
# 4              Not_Applicable  Not_Applicable                     02_Urgency
#
#   REFERRAL_DESION_DATE REFERRAL_REQUEST_RECEIVED_DATE_DF CONSULTANT_CODE
# 0  2017-01-01 11:59:09               2017-01-06 21:37:09         GMP-DR3
# ...

# %%
def fun1(x):
    if (str(x['CONSULTANT_CODE']).startswith("GMP-DR1")):
        return "370_MEDICAL ONCOLOGY"
    if (str(x['CONSULTANT_CODE']).startswith("GMP-DR2")):
        return "800_  CLINICAL ONCOLOGY"
    if (str(x['CONSULTANT_CODE']).startswith("GMP-DR3")):
        return "823_HAEMATOLOGY"
    if (str(x['CONSULTANT_CODE']).startswith("GMP-DR4")):
        return "824_HISTOPATHOLOGY"

# %%
wokng['MAIN_SPECIALITY_CODE']=wokng.apply(fun1,axis=1)

# %%
writer = pd.ExcelWriter('cancer_data.xlsx', engine='xlsxwriter')
working_sheet1.to_excel(writer,sheet_name="DEMOGRAPHICS",index=None)
wokng.to_excel(writer,sheet_name='REFERRAL',index=None)
writer.save()

# %%
temp=pd.concat([cancer_data_sheet1['statename'],cancer_data_sheet2['REFERRAL_REQUEST_RECEIVED_DATE_DF'],cancer_data_sheet2['LOCAL_PATIENT_IDENTIFIER']],axis=1)
temp.head()
# Out:
#    statename REFERRAL_REQUEST_RECEIVED_DATE_DF LOCAL_PATIENT_IDENTIFIER
# 0     KERALA               2017-01-06 21:37:09                 L_CPP100
# 1     KERALA               2017-01-07 09:06:57                 R_CPP101
# 2  KARNATAKA               2017-01-08 00:13:24                 L_CPP102
# 3     KERALA               2017-01-08 02:48:52                 L_CPP103
# 4     KERALA               2017-01-08 05:11:12                 L_CPP104

# %%
def fun4(x):
    if (str(x['statename']).startswith("KE")) and (str(x['LOCAL_PATIENT_IDENTIFIER']).startswith("R_")) :
        return x['REFERRAL_REQUEST_RECEIVED_DATE_DF']+datetime.timedelta(days=random.randint(20,25),hours=random.randint(7,11))
    if (str(x['statename']).startswith("KE")) and (str(x['LOCAL_PATIENT_IDENTIFIER']).startswith("L_")) :
        return x['REFERRAL_REQUEST_RECEIVED_DATE_DF']+datetime.timedelta(days=random.randint(19,24),hours=random.randint(7,11))
    if (str(x['statename']).startswith("KA")) or (str(x['statename']).startswith("TAMIL NADU")) and (str(x['LOCAL_PATIENT_IDENTIFIER']).startswith("R_")):
        return x['REFERRAL_REQUEST_RECEIVED_DATE_DF']+datetime.timedelta(days=random.randint(35,36),hours=random.randint(7,11))
    if (str(x['statename']).startswith("KA")) or (str(x['statename']).startswith("TAMIL NADU")) and (str(x['LOCAL_PATIENT_IDENTIFIER']).startswith("L_")):
        return x['REFERRAL_REQUEST_RECEIVED_DATE_DF']+datetime.timedelta(days=random.randint(25,27),hours=random.randint(7,11))

# %%
wokng['DATE_FIRST_SEEN']=temp.apply(fun4,axis=1)

# %%
wokng['DATE_FIRST_SEEN']
# Out:
# 0     2017-01-26 05:37:09
# 1     2017-01-29 18:06:57
# 2     2017-02-13 09:13:24
# 3     2017-01-31 09:48:52
# 4     2017-01-27 15:11:12
# 5     2017-01-31 20:10:53
# 6     2017-01-29 06:07:21
# 7     2017-01-29 16:55:02
# 8     2017-02-15 09:03:59
# 9     2017-02-16 10:12:41
# 10    2017-02-02 12:49:15
# 11    2017-02-05 21:36:05
# 12    2017-02-05 22:03:55
# 13    2017-02-05 03:39:12
# 14    2017-02-06 07:11:33
# 15    2017-02-08 07:03:36
# 16    2017-02-05 12:53:47
# 17    2017-02-03 15:44:10
# 18    2017-02-07 19:40:43
# 19    2017-02-02 00:01:11
# 20    2017-02-06 18:59:51
# 21    2017-02-03 09:53:32
# 22    2017-02-10 11:27:06
# 23    2017-02-10 12:15:08
# 24    2017-02-20 12:05:41
# 25    2017-02-20 23:49:47
# 26    2017-02-08 00:31:50
# 27    2017-02-10 02:49:45
# 28    2017-02-06 08:21:15
# 29    2017-02-09 11:41:54
#               ...
# 870                   NaT
# 871                   NaT
# 872                   NaT
# 873                   NaT
# 874                   NaT
# ...

# %%
temp
# Out:
#       statename REFERRAL_DESION_DATE REFERRAL_REQUEST_RECEIVED_DATE_DF  \
# 0        KERALA  2017-01-01 11:59:09               2017-01-06 21:37:09
# 1        KERALA  2017-01-01 23:28:57               2017-01-07 09:06:57
# 2     KARNATAKA  2017-01-02 14:35:24               2017-01-08 00:13:24
# 3        KERALA  2017-01-02 17:10:52               2017-01-08 02:48:52
# 4        KERALA  2017-01-02 19:33:12               2017-01-08 05:11:12
# 5        KERALA  2017-01-03 02:32:53               2017-01-08 12:10:53
# 6        KERALA  2017-01-03 10:29:21               2017-01-08 20:07:21
# 7        KERALA  2017-01-04 23:17:02               2017-01-10 08:55:02
# 8    TAMIL NADU  2017-01-05 13:25:59               2017-01-10 23:03:59
# 9     KARNATAKA  2017-01-05 17:34:41               2017-01-11 03:12:41
# 10       KERALA  2017-01-05 18:11:15               2017-01-11 03:49:15
# 11   TAMIL NADU  2017-01-06 01:58:05               2017-01-11 11:36:05
# ...

# %%
writer = pd.ExcelWriter('cancer_data.xlsx', engine='xlsxwriter')
working_sheet1.to_excel(writer,sheet_name="DEMOGRAPHICS",index=None)
wokng.to_excel(writer,sheet_name='REFERRAL',index=None)
writer.save()

# %%
def fun5(x):
        return x['DATE_FIRST_SEEN']-x['REFERRAL_REQUEST_RECEIVED_DATE_DF']

# %%
wokng['WAITING_TIME_ADJUSTMENT(FIRST_SEEN)']=temp.apply(fun5,axis=1)

# %%
wokng['WAITING_TIME_ADJUSTMENT(FIRST_SEEN)_str']=wokng['WAITING_TIME_ADJUSTMENT(FIRST_SEEN)'].apply(lambda x:str(x))

# %%
wokng
# Out:
#     LOCAL_PATIENT_IDENTIFIER SOURCE_OF_REFERRAL_FOR_CANCER  \
# 0                   L_CPP100                Not_Applicable
# 1                   R_CPP101   03_Referral from Consultant
# 2                   L_CPP102                Not_Applicable
# 3                   L_CPP103                Not_Applicable
# 4                   L_CPP104                Not_Applicable
# 5                   L_CPP105                Not_Applicable
# 6                   R_CPP106        05_Private Health Care
# 7                   L_CPP107                Not_Applicable
# 8                   R_CPP108   03_Referral from Consultant
# 9                   L_CPP109                Not_Applicable
# 10                  L_CPP110                Not_Applicable
# 11                  L_CPP111                Not_Applicable
# 12                  L_CPP112                Not_Applicable
# 13                  L_CPP113                Not_Applicable
# 14                  L_CPP114                Not_Applicable
# ...

# %%
temp=pd.concat([cancer_data_sheet1['statename'],wokng["REFERRAL_DESION_DATE"],wokng['REFERRAL_REQUEST_RECEIVED_DATE_DF'],wokng['DATE_FIRST_SEEN'],cancer_data_sheet2['LOCAL_PATIENT_IDENTIFIER']],axis=1)
temp.head(20)
# Out:
#      statename REFERRAL_DESION_DATE REFERRAL_REQUEST_RECEIVED_DATE_DF  \
# 0       KERALA  2017-01-01 11:59:09               2017-01-06 21:37:09
# 1       KERALA  2017-01-01 23:28:57               2017-01-07 09:06:57
# 2    KARNATAKA  2017-01-02 14:35:24               2017-01-08 00:13:24
# 3       KERALA  2017-01-02 17:10:52               2017-01-08 02:48:52
# 4       KERALA  2017-01-02 19:33:12               2017-01-08 05:11:12
# 5       KERALA  2017-01-03 02:32:53               2017-01-08 12:10:53
# 6       KERALA  2017-01-03 10:29:21               2017-01-08 20:07:21
# 7       KERALA  2017-01-04 23:17:02               2017-01-10 08:55:02
# 8   TAMIL NADU  2017-01-05 13:25:59               2017-01-10 23:03:59
# 9    KARNATAKA  2017-01-05 17:34:41               2017-01-11 03:12:41
# 10      KERALA  2017-01-05 18:11:15               2017-01-11 03:49:15
# 11  TAMIL NADU  2017-01-06 01:58:05               2017-01-11 11:36:05
# ...

# %%
working_sheet1['LOCAL_PATIENT_IDENTIFIER']=wokng['LOCAL_PATIENT_IDENTIFIER']

# %%
writer = pd.ExcelWriter('cancer_data.xlsx', engine='xlsxwriter')
working_sheet1.to_excel(writer,sheet_name="DEMOGRAPHICS",index=None)
wokng.to_excel(writer,sheet_name='REFERRAL',index=None)
writer.save()

# %%
typ=["02_Urgency",'01_Urgent']*900
sa=random.sample(typ,900)
def fun6(x):
    if (str(x['LOCAL_PATIENT_IDENTIFIER']).startswith("L_")) :
        return "Not_Applicable"
    if (str(x['LOCAL_PATIENT_IDENTIFIER']).startswith("R_")) :
        return sa[random.randint(1,700)]

# %%
wokng['CANCER_REFERRAL_PRIORITY_TYPES']=wokng.apply(fun6,axis=1)

# %%
#wokng=pd.read_excel("cancer_data.xlsx",sheet_name="REFERRAL")

# %%
dely_reson=["02_Out-patient capacity inadequate","03_Administrative delay","03_Administrative delay","04_Referral not received within 24 hours"]*900
dely_reson_sa=random.sample(dely_reson,900)

# %%
def fun3(x):
    if str(x['LOCAL_PATIENT_IDENTIFIER']).startswith("L"):
        return dely_reson_sa[random.randint(0,10)]
    if str(x['LOCAL_PATIENT_IDENTIFIER']).startswith("R"):
        return "99_Other"

# %%
wokng['DELAY_REASON_REFERRAL_TO_FIRST_SEEN_(CANCER)']=wokng.apply(fun3,axis=1)

# %%
writer = pd.ExcelWriter('cancer_data.xlsx', engine='xlsxwriter')
working_sheet1.to_excel(writer,sheet_name="DEMOGRAPHICS",index=None)
wokng.to_excel(writer,sheet_name='REFERRAL',index=None)
writer.save()

# %%
wokng_img=pd.concat([wokng["LOCAL_PATIENT_IDENTIFIER"]],axis=1)

# %%
wokng_img['SITE_CODE_IMAGING']=wokng_img.LOCAL_PATIENT_IDENTIFIER.apply(lambda x: str(x)+"_MCC")

# %%
writer = pd.ExcelWriter('cancer_data.xlsx', engine='xlsxwriter')
working_sheet1.to_excel(writer,sheet_name="DEMOGRAPHICS",index=None)
wokng.to_excel(writer,sheet_name='REFERRAL',index=None)
wokng_img.to_excel(writer,sheet_name='IMAGING',index=None)
writer.save()

# %%
wokng_img['CLINICAL_INTERVENTION_DATES(CANCER_IMAGING)']=wokng['DATE_FIRST_SEEN'].apply(lambda x: x+datetime.timedelta(days=3,hours=(random.randint(1,12))))

# %%
writer = pd.ExcelWriter('cancer_data.xlsx', engine='xlsxwriter')
working_sheet1.to_excel(writer,sheet_name="DEMOGRAPHICS",index=None)
wokng.to_excel(writer,sheet_name='REFERRAL',index=None)
wokng_img.to_excel(writer,sheet_name='IMAGING',index=None)
writer.save()

# %%
#wokng.drop(columns=['delay',"WAITING_TIME_ADJUSTMENT(FIRST_SEEN)"],axis=1,inplace=True)

# %%
wokng
# Out:
#     LOCAL_PATIENT_IDENTIFIER SOURCE_OF_REFERRAL_FOR_CANCER  \
# 0                   L_CPP100                Not_Applicable
# 1                   R_CPP101   03_Referral from Consultant
# 2                   L_CPP102                Not_Applicable
# 3                   L_CPP103                Not_Applicable
# 4                   L_CPP104                Not_Applicable
# 5                   L_CPP105                Not_Applicable
# 6                   R_CPP106        05_Private Health Care
# 7                   L_CPP107                Not_Applicable
# 8                   R_CPP108   03_Referral from Consultant
# 9                   L_CPP109                Not_Applicable
# 10                  L_CPP110                Not_Applicable
# 11                  L_CPP111                Not_Applicable
# 12                  L_CPP112                Not_Applicable
# 13                  L_CPP113                Not_Applicable
# 14                  L_CPP114                Not_Applicable
# ...

# %%
wokng['DELAY_REASON_TO_REFERRAL']
