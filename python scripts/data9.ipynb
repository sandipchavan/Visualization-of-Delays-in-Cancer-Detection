# %%
import pandas as pd
from pandas import DataFrame as df
import random
import datetime

# %%
df1=pd.read_excel('cancer_data4.xlsx',sheet_name="DEMOGRAPHICS")
df2=pd.read_excel('cancer_data4.xlsx',sheet_name='REFERRAL')
df3=pd.read_excel('cancer_data4.xlsx',sheet_name='IMAGING')
df4=pd.read_excel('cancer_data4.xlsx',sheet_name='DIAGNOSIS')
df5=pd.read_excel('cancer_data4.xlsx',sheet_name='CANCER CARE PLAN')
df6=pd.read_excel('cancer_data4.xlsx',sheet_name='Staging')
df7=pd.read_excel('cancer_data4.xlsx',sheet_name='Surgery&other procedures')
df8=pd.read_excel('cancer_data4.xlsx',sheet_name='Pathology Details')
df9=pd.read_excel("cancer_data4.xlsx",sheet_name="chemotheropy & other drugs")
df10=pd.read_excel("cancer_data4.xlsx",sheet_name="Radiotherapy(Teletherapy)")
df11=pd.read_excel("cancer_data4.xlsx",sheet_name='Radiotherapy(Brachytherapy)')
df12=pd.read_excel("cancer_data4.xlsx",sheet_name='Palliative Care')
df13=pd.read_excel("cancer_data4.xlsx",sheet_name='Clinical Trials')
df14=pd.read_excel("cancer_data4.xlsx",sheet_name='Clinical Status Assesment')

# %%
df14.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER CLINICAL STATUS ASSESSMENT DATE (CANCER)  \
# 0                 L_CPP100                               2017-05-09
# 1                 R_CPP101                               2017-06-02
# 2                 L_CPP102                               2017-06-02
# 3                 L_CPP103                               2017-05-22
# 4                 L_CPP104                               2017-06-03
#
#         PRIMARY TUMOUR STATUS                          NODAL STATUS  \
# 0                 5_Uncertain                           5_Uncertain
# 1   1_Residual primary tumour                        4_Not assessed
# 2                 5_Uncertain       3_New regional nodal metastases
# 3  3_Recurrent primary tumour  1_Residual regional nodal metastases
# 4                 5_Uncertain  1_Residual regional nodal metastases
#
#                METASTATIC STATUS MARKER RESPONSE STATUS  \
# 0       3_New distant metastases            1_No marker
# 1                 4_Not assessed       3_Static disease
# 2       3_New distant metastases            1_No marker
# 3    2_No evidence of metastases       3_Static disease
# 4  1_Residual distant metastases     4_Partial response
#
#                           PERFORMANCE STATUS (ADULT)  \
# 0  0_Able to carry out all normal activity withou...
# 1  2_Able to walk and capable of all self care, b...
# 2  1_Restricted in physically strenuous activity,...
# 3  1_Restricted in physically strenuous activity,...
# 4  2_Able to walk and capable of all self care, b...
#
#   TREATMENT TYPE (CANCER MORBIDITY) MORBIDITY CODE (CANCER SURGERY)  \
# 0                     4_Combination               d_Third secondary
# 1                         1_Surgery              e_Fourth secondary
# 2                    2_Chemotherapy               b_First secondary
# 3                         1_Surgery              e_Fourth secondary
# 4                    2_Chemotherapy               b_First secondary
#
#   PATIENT FOLLOW-UP STATUS (CANCER) MORBIDITY CODE (CHEMOTHERAPY)  \
# 0     4_Transferred to another unit             4_Severe toxicity
# 1                 1_Under follow-up           3_Moderate toxicity
# 2     4_Transferred to another unit       5_Death due to toxicity
# 3                 1_Under follow-up               2_Mild toxicity
# 4                 1_Under follow-up               2_Mild toxicity
#
#   MORBIDITY CODE (RADIOTHERAPY) MORBIDITY CODE (COMBINATION)
# 0           3_Moderate toxicity          3_Moderate toxicity
# 1           3_Moderate toxicity          3_Moderate toxicity
# 2             4_Severe toxicity          3_Moderate toxicity
# 3           3_Moderate toxicity          3_Moderate toxicity
# 4           3_Moderate toxicity          3_Moderate toxicity

# %%
lst=["2_Chemotherapy",
"3_Radiotherapy",
"4_Combination",
"1_Surgery",
"1_Surgery"
]

# %%
df14['TREATMENT TYPE (CANCER MORBIDITY)']=df14.apply(lambda x:lst[random.randint(0,4)],axis=1)

# %%
df14.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER CLINICAL STATUS ASSESSMENT DATE (CANCER)  \
# 0                 L_CPP100                               2017-05-09
# 1                 R_CPP101                               2017-06-02
# 2                 L_CPP102                               2017-06-02
# 3                 L_CPP103                               2017-05-22
# 4                 L_CPP104                               2017-06-03
#
#         PRIMARY TUMOUR STATUS                          NODAL STATUS  \
# 0                 5_Uncertain                           5_Uncertain
# 1   1_Residual primary tumour                        4_Not assessed
# 2                 5_Uncertain       3_New regional nodal metastases
# 3  3_Recurrent primary tumour  1_Residual regional nodal metastases
# 4                 5_Uncertain  1_Residual regional nodal metastases
#
#                METASTATIC STATUS MARKER RESPONSE STATUS  \
# 0       3_New distant metastases            1_No marker
# 1                 4_Not assessed       3_Static disease
# 2       3_New distant metastases            1_No marker
# 3    2_No evidence of metastases       3_Static disease
# 4  1_Residual distant metastases     4_Partial response
#
#                           PERFORMANCE STATUS (ADULT)  \
# 0  0_Able to carry out all normal activity withou...
# 1  2_Able to walk and capable of all self care, b...
# 2  1_Restricted in physically strenuous activity,...
# 3  1_Restricted in physically strenuous activity,...
# 4  2_Able to walk and capable of all self care, b...
#
#   TREATMENT TYPE (CANCER MORBIDITY) MORBIDITY CODE (CANCER SURGERY)  \
# 0                    2_Chemotherapy               d_Third secondary
# 1                         1_Surgery              e_Fourth secondary
# 2                         1_Surgery               b_First secondary
# 3                    3_Radiotherapy              e_Fourth secondary
# 4                    2_Chemotherapy               b_First secondary
#
#   PATIENT FOLLOW-UP STATUS (CANCER) MORBIDITY CODE (CHEMOTHERAPY)  \
# 0     4_Transferred to another unit             4_Severe toxicity
# 1                 1_Under follow-up           3_Moderate toxicity
# 2     4_Transferred to another unit       5_Death due to toxicity
# 3                 1_Under follow-up               2_Mild toxicity
# 4                 1_Under follow-up               2_Mild toxicity
#
#   MORBIDITY CODE (RADIOTHERAPY) MORBIDITY CODE (COMBINATION)
# 0           3_Moderate toxicity          3_Moderate toxicity
# 1           3_Moderate toxicity          3_Moderate toxicity
# 2             4_Severe toxicity          3_Moderate toxicity
# 3           3_Moderate toxicity          3_Moderate toxicity
# 4           3_Moderate toxicity          3_Moderate toxicity

# %%
lst=["b_First secondary",
"g_Other",
"d_Third secondary",
"e_Fourth secondary",
"c_Second secondary",
"a_Primary",
"f_Fifth secondary"
]

# %%
df14['MORBIDITY CODE (CANCER SURGERY)']=df14.apply(lambda x:lst[random.randint(0,6)],axis=1)

# %%
df14.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER CLINICAL STATUS ASSESSMENT DATE (CANCER)  \
# 0                 L_CPP100                               2017-05-09
# 1                 R_CPP101                               2017-06-02
# 2                 L_CPP102                               2017-06-02
# 3                 L_CPP103                               2017-05-22
# 4                 L_CPP104                               2017-06-03
#
#         PRIMARY TUMOUR STATUS                          NODAL STATUS  \
# 0                 5_Uncertain                           5_Uncertain
# 1   1_Residual primary tumour                        4_Not assessed
# 2                 5_Uncertain       3_New regional nodal metastases
# 3  3_Recurrent primary tumour  1_Residual regional nodal metastases
# 4                 5_Uncertain  1_Residual regional nodal metastases
#
#                METASTATIC STATUS MARKER RESPONSE STATUS  \
# 0       3_New distant metastases            1_No marker
# 1                 4_Not assessed       3_Static disease
# 2       3_New distant metastases            1_No marker
# 3    2_No evidence of metastases       3_Static disease
# 4  1_Residual distant metastases     4_Partial response
#
#                           PERFORMANCE STATUS (ADULT)  \
# 0  0_Able to carry out all normal activity withou...
# 1  2_Able to walk and capable of all self care, b...
# 2  1_Restricted in physically strenuous activity,...
# 3  1_Restricted in physically strenuous activity,...
# 4  2_Able to walk and capable of all self care, b...
#
#   TREATMENT TYPE (CANCER MORBIDITY) MORBIDITY CODE (CANCER SURGERY)
# 0                     4_Combination               d_Third secondary
# 1                         1_Surgery              e_Fourth secondary
# 2                    2_Chemotherapy               b_First secondary
# 3                         1_Surgery              e_Fourth secondary
# 4                    2_Chemotherapy               b_First secondary

# %%
lst=["1_Under follow-up",
"3_Discharged",
"4_Transferred to another unit",
"2_Lost to follow-up", 
"1_Under follow-up"
]

# %%
df14['PATIENT FOLLOW-UP STATUS (CANCER)']=df14.apply(lambda x:lst[random.randint(0,4)],axis=1)

# %%
df14.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER CLINICAL STATUS ASSESSMENT DATE (CANCER)  \
# 0                 L_CPP100                               2017-05-09
# 1                 R_CPP101                               2017-06-02
# 2                 L_CPP102                               2017-06-02
# 3                 L_CPP103                               2017-05-22
# 4                 L_CPP104                               2017-06-03
#
#         PRIMARY TUMOUR STATUS                          NODAL STATUS  \
# 0                 5_Uncertain                           5_Uncertain
# 1   1_Residual primary tumour                        4_Not assessed
# 2                 5_Uncertain       3_New regional nodal metastases
# 3  3_Recurrent primary tumour  1_Residual regional nodal metastases
# 4                 5_Uncertain  1_Residual regional nodal metastases
#
#                METASTATIC STATUS MARKER RESPONSE STATUS  \
# 0       3_New distant metastases            1_No marker
# 1                 4_Not assessed       3_Static disease
# 2       3_New distant metastases            1_No marker
# 3    2_No evidence of metastases       3_Static disease
# 4  1_Residual distant metastases     4_Partial response
#
#                           PERFORMANCE STATUS (ADULT)  \
# 0  0_Able to carry out all normal activity withou...
# 1  2_Able to walk and capable of all self care, b...
# 2  1_Restricted in physically strenuous activity,...
# 3  1_Restricted in physically strenuous activity,...
# 4  2_Able to walk and capable of all self care, b...
#
#   TREATMENT TYPE (CANCER MORBIDITY) MORBIDITY CODE (CANCER SURGERY)  \
# 0                     4_Combination               d_Third secondary
# 1                         1_Surgery              e_Fourth secondary
# 2                    2_Chemotherapy               b_First secondary
# 3                         1_Surgery              e_Fourth secondary
# 4                    2_Chemotherapy               b_First secondary
#
#   PATIENT FOLLOW-UP STATUS (CANCER)
# 0     4_Transferred to another unit
# 1                 1_Under follow-up
# 2     4_Transferred to another unit
# 3                 1_Under follow-up
# 4                 1_Under follow-up

# %%
lst=["2_Mild toxicity",
"3_Moderate toxicity",
"2_Mild toxicity",
"2_Mild toxicity",
"4_Severe toxicity",
"5_Death due to toxicity"
]

# %%
df14['MORBIDITY CODE (CHEMOTHERAPY)']=df14.apply(lambda x:lst[random.randint(0,5)],axis=1)

# %%
df14.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER CLINICAL STATUS ASSESSMENT DATE (CANCER)  \
# 0                 L_CPP100                               2017-05-09
# 1                 R_CPP101                               2017-06-02
# 2                 L_CPP102                               2017-06-02
# 3                 L_CPP103                               2017-05-22
# 4                 L_CPP104                               2017-06-03
#
#         PRIMARY TUMOUR STATUS                          NODAL STATUS  \
# 0                 5_Uncertain                           5_Uncertain
# 1   1_Residual primary tumour                        4_Not assessed
# 2                 5_Uncertain       3_New regional nodal metastases
# 3  3_Recurrent primary tumour  1_Residual regional nodal metastases
# 4                 5_Uncertain  1_Residual regional nodal metastases
#
#                METASTATIC STATUS MARKER RESPONSE STATUS  \
# 0       3_New distant metastases            1_No marker
# 1                 4_Not assessed       3_Static disease
# 2       3_New distant metastases            1_No marker
# 3    2_No evidence of metastases       3_Static disease
# 4  1_Residual distant metastases     4_Partial response
#
#                           PERFORMANCE STATUS (ADULT)  \
# 0  0_Able to carry out all normal activity withou...
# 1  2_Able to walk and capable of all self care, b...
# 2  1_Restricted in physically strenuous activity,...
# 3  1_Restricted in physically strenuous activity,...
# 4  2_Able to walk and capable of all self care, b...
#
#   TREATMENT TYPE (CANCER MORBIDITY) MORBIDITY CODE (CANCER SURGERY)  \
# 0                     4_Combination               d_Third secondary
# 1                         1_Surgery              e_Fourth secondary
# 2                    2_Chemotherapy               b_First secondary
# 3                         1_Surgery              e_Fourth secondary
# 4                    2_Chemotherapy               b_First secondary
#
#   PATIENT FOLLOW-UP STATUS (CANCER) MORBIDITY CODE (CHEMOTHERAPY)
# 0     4_Transferred to another unit             4_Severe toxicity
# 1                 1_Under follow-up           3_Moderate toxicity
# 2     4_Transferred to another unit       5_Death due to toxicity
# 3                 1_Under follow-up               2_Mild toxicity
# 4                 1_Under follow-up               2_Mild toxicity

# %%
lst=["3_Moderate toxicity",
"3_Moderate toxicity",
"4_Severe toxicity",
"5_Death due to toxicity",
"4_Severe toxicity"
]

# %%
df14['MORBIDITY CODE (RADIOTHERAPY)']=df14.apply(lambda x:lst[random.randint(0,4)],axis=1)

# %%
df14.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER CLINICAL STATUS ASSESSMENT DATE (CANCER)  \
# 0                 L_CPP100                               2017-05-09
# 1                 R_CPP101                               2017-06-02
# 2                 L_CPP102                               2017-06-02
# 3                 L_CPP103                               2017-05-22
# 4                 L_CPP104                               2017-06-03
#
#         PRIMARY TUMOUR STATUS                          NODAL STATUS  \
# 0                 5_Uncertain                           5_Uncertain
# 1   1_Residual primary tumour                        4_Not assessed
# 2                 5_Uncertain       3_New regional nodal metastases
# 3  3_Recurrent primary tumour  1_Residual regional nodal metastases
# 4                 5_Uncertain  1_Residual regional nodal metastases
#
#                METASTATIC STATUS MARKER RESPONSE STATUS  \
# 0       3_New distant metastases            1_No marker
# 1                 4_Not assessed       3_Static disease
# 2       3_New distant metastases            1_No marker
# 3    2_No evidence of metastases       3_Static disease
# 4  1_Residual distant metastases     4_Partial response
#
#                           PERFORMANCE STATUS (ADULT)  \
# 0  0_Able to carry out all normal activity withou...
# 1  2_Able to walk and capable of all self care, b...
# 2  1_Restricted in physically strenuous activity,...
# 3  1_Restricted in physically strenuous activity,...
# 4  2_Able to walk and capable of all self care, b...
#
#   TREATMENT TYPE (CANCER MORBIDITY) MORBIDITY CODE (CANCER SURGERY)  \
# 0                     4_Combination               d_Third secondary
# 1                         1_Surgery              e_Fourth secondary
# 2                    2_Chemotherapy               b_First secondary
# 3                         1_Surgery              e_Fourth secondary
# 4                    2_Chemotherapy               b_First secondary
#
#   PATIENT FOLLOW-UP STATUS (CANCER) MORBIDITY CODE (CHEMOTHERAPY)  \
# 0     4_Transferred to another unit             4_Severe toxicity
# 1                 1_Under follow-up           3_Moderate toxicity
# 2     4_Transferred to another unit       5_Death due to toxicity
# 3                 1_Under follow-up               2_Mild toxicity
# 4                 1_Under follow-up               2_Mild toxicity
#
#   MORBIDITY CODE (RADIOTHERAPY)
# 0           3_Moderate toxicity
# 1           3_Moderate toxicity
# 2             4_Severe toxicity
# 3           3_Moderate toxicity
# 4           3_Moderate toxicity

# %%
lst=["2_Mild toxicity",
"3_Moderate toxicity",
"3_Moderate toxicity",
"5_Death due to toxicity",
"4_Severe toxicity"
]

# %%
df14['MORBIDITY CODE (COMBINATION)']=df14.apply(lambda x:lst[random.randint(0,4)],axis=1)

# %%
df14.head()
# Out:
#   LOCAL_PATIENT_IDENTIFIER CLINICAL STATUS ASSESSMENT DATE (CANCER)  \
# 0                 L_CPP100                               2017-05-09
# 1                 R_CPP101                               2017-06-02
# 2                 L_CPP102                               2017-06-02
# 3                 L_CPP103                               2017-05-22
# 4                 L_CPP104                               2017-06-03
#
#         PRIMARY TUMOUR STATUS                          NODAL STATUS  \
# 0                 5_Uncertain                           5_Uncertain
# 1   1_Residual primary tumour                        4_Not assessed
# 2                 5_Uncertain       3_New regional nodal metastases
# 3  3_Recurrent primary tumour  1_Residual regional nodal metastases
# 4                 5_Uncertain  1_Residual regional nodal metastases
#
#                METASTATIC STATUS MARKER RESPONSE STATUS  \
# 0       3_New distant metastases            1_No marker
# 1                 4_Not assessed       3_Static disease
# 2       3_New distant metastases            1_No marker
# 3    2_No evidence of metastases       3_Static disease
# 4  1_Residual distant metastases     4_Partial response
#
#                           PERFORMANCE STATUS (ADULT)  \
# 0  0_Able to carry out all normal activity withou...
# 1  2_Able to walk and capable of all self care, b...
# 2  1_Restricted in physically strenuous activity,...
# 3  1_Restricted in physically strenuous activity,...
# 4  2_Able to walk and capable of all self care, b...
#
#   TREATMENT TYPE (CANCER MORBIDITY) MORBIDITY CODE (CANCER SURGERY)  \
# 0                     4_Combination               d_Third secondary
# 1                         1_Surgery              e_Fourth secondary
# 2                    2_Chemotherapy               b_First secondary
# 3                         1_Surgery              e_Fourth secondary
# 4                    2_Chemotherapy               b_First secondary
#
#   PATIENT FOLLOW-UP STATUS (CANCER) MORBIDITY CODE (CHEMOTHERAPY)  \
# 0     4_Transferred to another unit             4_Severe toxicity
# 1                 1_Under follow-up           3_Moderate toxicity
# 2     4_Transferred to another unit       5_Death due to toxicity
# 3                 1_Under follow-up               2_Mild toxicity
# 4                 1_Under follow-up               2_Mild toxicity
#
#   MORBIDITY CODE (RADIOTHERAPY) MORBIDITY CODE (COMBINATION)
# 0           3_Moderate toxicity          3_Moderate toxicity
# 1           3_Moderate toxicity          3_Moderate toxicity
# 2             4_Severe toxicity          3_Moderate toxicity
# 3           3_Moderate toxicity          3_Moderate toxicity
# 4           3_Moderate toxicity          3_Moderate toxicity

# %%
writer = pd.ExcelWriter('cancer_data5.xlsx', engine='xlsxwriter')
df1.to_excel(writer,sheet_name="DEMOGRAPHICS",index=None)
df2.to_excel(writer,sheet_name='REFERRAL',index=None)
df3.to_excel(writer,sheet_name='IMAGING',index=None)
df4.to_excel(writer,sheet_name='DIAGNOSIS',index=None)
df5.to_excel(writer,sheet_name='CANCER CARE PLAN',index=None)
df6.to_excel(writer,sheet_name='Staging',index=None)
df7.to_excel(writer,sheet_name='Surgery&other procedures',index=None)
df8.to_excel(writer,sheet_name='Pathology Details',index=None)
df9.to_excel(writer,sheet_name='chemotheropy & other drugs',index=None)
df10.to_excel(writer,sheet_name='Radiotherapy(Teletherapy)',index=None)
df11.to_excel(writer,sheet_name='Radiotherapy(Brachytherapy)',index=None)
df12.to_excel(writer,sheet_name='Palliative Care',index=None)
df13.to_excel(writer,sheet_name='Clinical Trials',index=None)
df14.to_excel(writer,sheet_name='Clinical Status Assesment',index=None)
df15.to_excel(writer,sheet_name='Death Details',index=None)
writer.save()

# %%
df15=pd.DataFrame()

# %%
df15['LOCAL_PATIENT_IDENTIFIER']=df1["LOCAL_PATIENT_IDENTIFIER"]

# %%
df15['PERSON DEATH DATE']=df14.apply(lambda x:x["CLINICAL STATUS ASSESSMENT DATE (CANCER)"]+datetime.timedelta(days=random.randint(180,200)),axis=1)

# %%
# Out:
#   LOCAL_PATIENT_IDENTIFIER PERSON DEATH DATE
# 0                 L_CPP100        2017-11-09
# 1                 R_CPP101        2017-12-09
# 2                 L_CPP102        2017-12-03
# 3                 L_CPP103        2017-12-08
# 4                 L_CPP104        2017-12-04

# %%
lst1=random.sample(range(0,600),221)

# %%
def fun1(x):
