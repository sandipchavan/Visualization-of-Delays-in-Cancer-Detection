# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
a = np.linspace(0,5,11)
b = a**2

# %%
a
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
b
# Out:
# array([  0.  ,   0.25,   1.  ,   2.25,   4.  ,   6.25,   9.  ,  12.25,
#         16.  ,  20.25,  25.  ])

# %%
plt.plot(a,b)
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('first')

# %%
plt.subplot(1,2,1)
plt.plot(a,b,'r')

plt.subplot(1,2,2)
plt.plot(b,a,'b')

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(a,b)

# %%
fig,axes = plt.subplots(nrows=3,ncols=3)

for i in range(0,3):
    for j in range(0,3):
        axes[i][j].plot(a,b)

# %%
fig.savefig('myfig.png',dpi=200)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(a,a**2,label='X Squared')
ax.plot(a,a**3,label='X Cubed')

ax.legend(loc=0)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
#  efljnfjl

# %%
df1=pd.read_excel('/home/rallypoint/Downloads/cancer_data3.xlsx','DEMOGRAPHICS')

# %%
import pandas as pd

# %%
from pandas import DataFrame as df

# %%
from pandas import Series as s

# %%
df1
# Out:
#      NHS NUMBER LOCAL_PATIENT_IDENTIFIER       NAME GENDER  AGE  pincode  \
# 0        101111                 L_CPP100    Addison      M   75   678572
# 1        101112                 R_CPP101     Darrel      M   39   679333
# 2        101114                 L_CPP102      Jerry      M   47   577132
# 3        101115                 L_CPP103     Karina      F   78   686693
# 4        101117                 L_CPP104   Madeline      F   67   679307
# 5        101126                 L_CPP105      Emani      F   42   670704
# 6        101127                 R_CPP106      Wilma      F   49   678633
# 7        101132                 L_CPP107      Shawn      M   68   683516
# 8        101134                 R_CPP108       Eric      M   61   637102
# 9        101137                 L_CPP109    Cathryn      F   52   585317
# 10       101138                 L_CPP110     Jennie      F   78   680669
# 11       101139                 L_CPP111      Barry      M   59   641301
# ...

# %%
def fun1(x):
    if (str(x.LOCAL_PATIENT_IDENTIFIER).startswith('R') )  and ( str(x['statename']).startswith("KA") or str(x["statename"]).startswith("TAMIL NADU") ):
        return "kl-r"

# %%
f1=len(df1.apply(fun1,axis=1).dropna())

# %%
f1
# Out:
# 115

# %%
def fun2(x):
    if (str(x['LOCAL_PATIENT_IDENTIFIER']).startswith('L_') )  and ( str(x['statename']).startswith("KA") or str(x["statename"]).startswith("TAMIL NADU") ):
        return 'outsider-L'
    if ( str(x["LOCAL_PATIENT_IDENTIFIER"]).startswith("R_") ) and (  str(x['statename']).startswith("KA") or str(x["statename"]).startswith("TAMIL NADU")    ):
        return "outside-R"
    if  str(x["LOCAL_PATIENT_IDENTIFIER"]).startswith("L_")  and   str(x['statename']).startswith("KE")   :
        return "inside-L"
    if  str(x["LOCAL_PATIENT_IDENTIFIER"]).startswith("R_")  and   str(x['statename']).startswith("KE")   :
        return "inside-R"

# %%
df1.head()
# Out:
#    NHS NUMBER LOCAL_PATIENT_IDENTIFIER      NAME GENDER  AGE  pincode  \
# 0      101111                 L_CPP100   Addison      M   75   678572
# 1      101112                 R_CPP101    Darrel      M   39   679333
# 2      101114                 L_CPP102     Jerry      M   47   577132
# 3      101115                 L_CPP103    Karina      F   78   686693
# 4      101117                 L_CPP104  Madeline      F   67   679307
#
#            Taluk  statename CARE_SPELL_IDENTIFIER       GMP ETHNIC_CATEGORY
# 0        Alathur     KERALA                   OWN  GMP-DR11             BPL
# 1       Nilambur     KERALA                 GOV-A  GMP-DR19             HCL
# 2       Mudigere  KARNATAKA           GOV-DEFENCE   GMP-DR2             MCL
# 3  Kothamangalam     KERALA           GOV-RAILWAY   GMP-DR4             HCL
# 4     Ottappalam     KERALA           GOV-DEFENCE   GMP-DR4             MCL

# %%
new_df1['ref']=df1.apply(fun2,axis=1)

# %%
f2=new_df1.groupby(['ref']).count()

# %%
dfs=df(f2)
dfs.values
# Out:
# array([[195],
#        [151],
#        [115],
#        [164]])

# %%
f2.plot(kind='bar',legend=True)

# %%
import seaborn as sns

# %%
sns.barplot(x=f2.index,y=f2)

# %%
import pygooglechart as pygl

# %%
from pygooglechart import PieChart3D

# %%
chart = PieChart3D(500, 500)

# %%
chart.add_data([398, 294, 840, 462])
# Out:
# 0

# %%
chart.set_pie_labels("Lithuania Bulgaria Ukraine Romania".split())

# %%
chart.download('revenue_east_europe.png')

# %%
f3=df1.groupby(['ETHNIC_CATEGORY','statename']).count()

# %%
f3
# Out:
#                             NHS NUMBER  LOCAL_PATIENT_IDENTIFIER  NAME  \
# ETHNIC_CATEGORY statename
# BPL             KARNATAKA           33                        33    33
#                 KERALA             107                       107   107
#                 TAMIL NADU          45                        45    45
# HCL             KARNATAKA           43                        43    43
#                 KERALA             124                       124   124
#                 TAMIL NADU          63                        63    63
# MCL             KARNATAKA           47                        47    47
#                 KERALA             115                       115   115
#                 TAMIL NADU          48                        48    48
#
#                             GENDER  AGE  pincode  Taluk  \
# ETHNIC_CATEGORY statename
# BPL             KARNATAKA       33   33       33     33
#                 KERALA         107  107      107    107
# ...

# %%
def fun4(z):
        if (str(z.ETHNIC_CATEGORY).startswith('B') )  and ( str(z['statename']).startswith("KE")  ):
            return 'b_kl'

# %%
len(df1.apply(fun4,axis=1).dropna())
# Out:
# 107

# %%
ff3=f3['NHS NUMBER']

# %%
ff3
# Out:
# ETHNIC_CATEGORY  statename
# BPL              KARNATAKA      33
#                  KERALA        107
#                  TAMIL NADU     45
# HCL              KARNATAKA      43
#                  KERALA        124
#                  TAMIL NADU     63
# MCL              KARNATAKA      47
#                  KERALA        115
#                  TAMIL NADU     48
# Name: NHS NUMBER, dtype: int64

# %%
f2=ff3["BPL"]

# %%
g.figure.set_size_inches(50,50)
g=sns.barplot(x=f2.index,y=f2)
g.axes.set_title('BPL CATEGORY')
g.axes.set_ylabel('NO OF PATIENTS')
g.axes.set_xlabel('STATES')

#g.axes.legend(['KARNATAKA','KERALA','TAMIL NADU'])

# %%
df1.head()
# Out:
#    NHS NUMBER LOCAL_PATIENT_IDENTIFIER      NAME GENDER  AGE  pincode  \
# 0      101111                 L_CPP100   Addison      M   75   678572
# 1      101112                 R_CPP101    Darrel      M   39   679333
# 2      101114                 L_CPP102     Jerry      M   47   577132
# 3      101115                 L_CPP103    Karina      F   78   686693
# 4      101117                 L_CPP104  Madeline      F   67   679307
#
#            Taluk  statename CARE_SPELL_IDENTIFIER       GMP ETHNIC_CATEGORY
# 0        Alathur     KERALA                   OWN  GMP-DR11             BPL
# 1       Nilambur     KERALA                 GOV-A  GMP-DR19             HCL
# 2       Mudigere  KARNATAKA           GOV-DEFENCE   GMP-DR2             MCL
# 3  Kothamangalam     KERALA           GOV-RAILWAY   GMP-DR4             HCL
# 4     Ottappalam     KERALA           GOV-DEFENCE   GMP-DR4             MCL

# %%
fg=df1.groupby('CARE_SPELL_IDENTIFIER').count()

# %%
fg
# Out:
#                        NHS NUMBER  LOCAL_PATIENT_IDENTIFIER  NAME  GENDER  \
# CARE_SPELL_IDENTIFIER
# GOV-A                          63                        63    63      63
# GOV-B                          67                        67    67      67
# GOV-DEFENCE                    52                        52    52      52
# GOV-MINES                      62                        62    62      62
# GOV-RAILWAY                    51                        51    51      51
# OWN                           330                       330   330     330
#
#                        AGE  pincode  Taluk  statename  GMP  ETHNIC_CATEGORY
# CARE_SPELL_IDENTIFIER
# GOV-A                   63       63     63         63   63               63
# GOV-B                   67       67     67         67   67               67
# GOV-DEFENCE             52       52     52         52   52               52
# GOV-MINES               62       62     62         62   62               62
# ...

# %%
r=fg['NHS NUMBER']
# Out:
# CARE_SPELL_IDENTIFIER
# GOV-A           63
# GOV-B           67
# GOV-DEFENCE     52
# GOV-MINES       62
# GOV-RAILWAY     51
# OWN            330
# Name: NHS NUMBER, dtype: int64

# %%
g.figure.set_size_inches(50,50)
g=sns.barplot(x=r.index,y=r)
g.axes.set_title('CARE_SPELL_IDENTIFIER')
g.axes.set_ylabel('NO OF PATIENTS')
g.axes.set_xlabel('STATES')
