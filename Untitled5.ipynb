# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %load imprt.txt
import numpy as np
import pandas as pd
from pandas import DataFrame as df
from pandas import Series as s
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
x=np.arange(1,10)
y=x*2

# %%
fig=plt.figure()
fig.set_size_inches(11.5,8)
axis=fig.add_axes([0.1,0.1,.8,.8])
axis.set_title("Temporary Title")
axis.set_xlabel("X-label")
axis.set_ylabel("Y-label")
axis.plot(x,y,'r')

# %%
plt.savefig('filename.png', bbox_inches='tight')

# %%
fig.savefig("temp.png")

# %%
fig,axes=plt.subplots(1,2)
axes[0].plot(x,y)
axes[1].plot(y,x,'r',ls='--',marker="o",markersize=10,color="purple")
plt.tight_layout()

# %%
 dataset=pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# %%
dataset.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(0)
n, p = 40, 8
d = np.random.normal(0, 2, (n, p))
d += np.log(np.arange(1, p + 1)) * -5 + 10


# plot
sns.set_style('ticks')
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(15, 9)
sns.violinplot(data=d, inner="points", ax=ax)    
sns.despine()

fig.savefig('example.png')
# Out:
# C:\Users\sandip\Anaconda2\lib\site-packages\seaborn\categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# C:\Users\sandip\Anaconda2\lib\site-packages\seaborn\categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
sns.set_style("ticks")
sns.distplot(dataset['tip'],bins=20,color='purple')

# %%
img1=sns.jointplot(x='total_bill',y='tip',data=dataset,kind='reg',color='red')

# %%
img1.savefig('data_kde.png')

# %%
sns.set_style('ticks')
sns.pairplot(data=dataset,size=4.5,hue='sex',plot_kws=dict())
